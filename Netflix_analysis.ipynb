# %% [markdown]
# ## Importation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../data/netflix_data.csv")

# %%
data
# Out:
#                              Title                                   Genre  \
# 0                 Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1              HOW TO BUILD A GIRL                                  Comedy
# 2                       Centigrade                         Drama, Thriller
# 3                            Moxie                 Animation, Short, Drama
# 4                 The Con-Heartist                         Comedy, Romance
# ...                            ...                                     ...
# 10530       District 13: Ultimatum                 Action, Crime, Thriller
# 10531               13 Going on 30                Comedy, Fantasy, Romance
# 10532                     LIFE 2.0                             Documentary
# 10533                Brand New Day                      Documentary, Music
# 10534  Daniel Arends: Blessuretijd                                  Comedy
#
#                                                     Tags            Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...     Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British              English
# 2                                              Thrillers              English
# 3      Social Issue Dramas,Teen Movies,Dramas,Comedie...              English
# 4      Romantic Comedies,Comedies,Romantic Films,Thai...                 Thai
# ...                                                  ...                  ...
# 10530  International Movies,Action Thrillers,French F...      French, English
# 10531  Romantic Comedies,Comedies,Romantic Films,Roma...  English, Portuguese
# 10532  Social & Cultural Documentaries,Biographical D...              English
# 10533  Australian Comedies,Romantic Comedies,Australi...              English
# 10534      Stand-up Comedy,International Movies,Comedies                Dutch
#
#       Series or Movie  Hidden Gem Score  \
# 0              Series               4.3
# 1               Movie               7.0
# 2               Movie               6.4
# 3               Movie               8.1
# 4               Movie               8.6
# ...               ...               ...
# 10530           Movie               3.4
# 10531           Movie               3.1
# 10532           Movie               8.2
# 10533           Movie               8.6
# 10534           Movie               8.8
#
#                                     Country Availability       Runtime  \
# 0                                               Thailand  < 30 minutes
# 1                                                 Canada      1-2 hour
# 2                                                 Canada      1-2 hour
# 3      Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# 4                                               Thailand       > 2 hrs
# ...                                                  ...           ...
# 10530                                             France      1-2 hour
# 10531  Hungary,Lithuania,Romania,United Kingdom,Belgi...      1-2 hour
# 10532  Hungary,Lithuania,India,Australia,United Kingd...      1-2 hour
# 10533                                          Australia      1-2 hour
# 10534                                            Belgium      1-2 hour
#
#                     Director  \
# 0            Tomas Alfredson
# 1              Coky Giedroyc
# 2              Brendan Walsh
# 3              Stephen Irwin
# 4              Mez Tharatorn
# ...                      ...
# 10530    Patrick Alessandrin
# 10531            Gary Winick
# 10532    Jason Spingarn-Koff
# 10533             Amos Gitai
# 10534  Doesjka van Hoogdalem
#
#                                                   Writer  ... IMDb Score  \
# 0                                  John Ajvide Lindqvist  ...        7.9
# 1                                          Caitlin Moran  ...        5.8
# 2                             Brendan Walsh, Daley Nixon  ...        4.3
# 3                                                Unknown  ...        6.3
# 4      Pattaranad Bhiboonsawade, Thodsapon Thiptinnak...  ...        7.4
# ...                                                  ...  ...        ...
# 10530                                         Luc Besson  ...        6.5
# 10531                        Josh Goldsmith, Cathy Yuspa  ...        6.2
# 10532                                            Unknown  ...        6.2
# 10533                                            Unknown  ...        7.3
# 10534                                      Daniël Arends  ...        7.8
#
#       Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                      98.0              82.0             74.0
# 1                      79.0              69.0              1.0
# 2                      -1.0              46.0              0.0
# 3                      -1.0              -1.0              0.0
# 4                      -1.0              -1.0              0.0
# ...                     ...               ...              ...
# 10530                  75.0              64.0              0.0
# 10531                  65.0              57.0              0.0
# 10532                  89.0              65.0              1.0
# 10533                  -1.0              -1.0              0.0
# 10534                  -1.0              -1.0              0.0
#
#        Awards Nominated For    Boxoffice  Netflix Release Date  \
# 0                      57.0   $2,122,065            2021-03-04
# 1                       0.0      $70,632            2021-03-04
# 2                       0.0      $16,263            2021-03-04
# 3                       4.0           $0            2021-03-04
# 4                       0.0           $0            2021-03-03
# ...                     ...          ...                   ...
# 10530                   1.0      $36,136            2015-04-14
# 10531                  11.0  $57,231,747            2015-04-14
# 10532                   0.0           $0            2015-04-14
# 10533                   0.0           $0            2015-04-14
# 10534                   0.0           $0            2015-04-14
#
#                                    Production House IMDb Votes Trailer Site
# 0                         Canal+, Sandrew Metronome   205926.0      Unknown
# 1            Film 4, Monumental Pictures, Lionsgate     2838.0      YouTube
# 2                                           Unknown     1720.0      YouTube
# 3                                           Unknown       63.0      Unknown
# 4                                           Unknown      131.0      YouTube
# ...                                             ...        ...          ...
# 10530                                       Unknown    42967.0      YouTube
# 10531  Revolution Studios, Thirteen Productions LLC   167842.0      YouTube
# 10532                                       Unknown      878.0      Unknown
# 10533                                       Unknown       14.0      Unknown
# 10534                                       Unknown      174.0      Unknown
#
# [10535 rows x 22 columns]

# %% [markdown]
# ## Analyse du dataset

# %%
print(f'Nombre de lignes : {data.shape[0]}')
print(f'Nombre de colonnes : {data.shape[1]}')
data.info()
# Out:
# Nombre de lignes : 10535
# Nombre de colonnes : 22
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10535 entries, 0 to 10534
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  10535 non-null  object
#  1   Genre                  10535 non-null  object
#  2   Tags                   10535 non-null  object
#  3   Languages              10535 non-null  object
#  4   Series or Movie        10535 non-null  object
#  5   Hidden Gem Score       10535 non-null  float64
#  6   Country Availability   10535 non-null  object
#  7   Runtime                10535 non-null  object
#  8   Director               10535 non-null  object
#  9   Writer                 10535 non-null  object
#  10  Actors                 10535 non-null  object
#  11  View Rating            10535 non-null  object
#  12  IMDb Score             10535 non-null  float64
#  13  Rotten Tomatoes Score  10535 non-null  float64
#  14  Metacritic Score       10535 non-null  float64
#  15  Awards Received        10535 non-null  float64
#  16  Awards Nominated For   10535 non-null  float64
#  17  Boxoffice              10535 non-null  object
#  18  Netflix Release Date   10535 non-null  object
#  19  Production House       10535 non-null  object
#  20  IMDb Votes             10535 non-null  float64
#  21  Trailer Site           10535 non-null  object
# dtypes: float64(7), object(15)
# memory usage: 1.8+ MB

# %%
data.isnull().sum()
# Out:
# Title                    0
# Genre                    0
# Tags                     0
# Languages                0
# Series or Movie          0
# Hidden Gem Score         0
# Country Availability     0
# Runtime                  0
# Director                 0
# Writer                   0
# Actors                   0
# View Rating              0
# IMDb Score               0
# Rotten Tomatoes Score    0
# Metacritic Score         0
# Awards Received          0
# Awards Nominated For     0
# Boxoffice                0
# Netflix Release Date     0
# Production House         0
# IMDb Votes               0
# Trailer Site             0
# dtype: int64

# %%
data[data['Country Availability'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Tags, Languages, Series or Movie, Hidden Gem Score, Country Availability, Runtime, Director, Writer, Actors, View Rating, IMDb Score, Rotten Tomatoes Score, Metacritic Score, Awards Received, Awards Nominated For, Boxoffice, Netflix Release Date, Production House, IMDb Votes, Trailer Site]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
numeriques = data.select_dtypes(include=["int64", "float64"])
categorielles = data.select_dtypes(include=["object", "category", "bool"])

# %%
data
# Out:
#                              Title                                   Genre  \
# 0                 Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1              HOW TO BUILD A GIRL                                  Comedy
# 2                       Centigrade                         Drama, Thriller
# 3                            Moxie                 Animation, Short, Drama
# 4                 The Con-Heartist                         Comedy, Romance
# ...                            ...                                     ...
# 10530       District 13: Ultimatum                 Action, Crime, Thriller
# 10531               13 Going on 30                Comedy, Fantasy, Romance
# 10532                     LIFE 2.0                             Documentary
# 10533                Brand New Day                      Documentary, Music
# 10534  Daniel Arends: Blessuretijd                                  Comedy
#
#                                                     Tags            Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...     Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British              English
# 2                                              Thrillers              English
# 3      Social Issue Dramas,Teen Movies,Dramas,Comedie...              English
# 4      Romantic Comedies,Comedies,Romantic Films,Thai...                 Thai
# ...                                                  ...                  ...
# 10530  International Movies,Action Thrillers,French F...      French, English
# 10531  Romantic Comedies,Comedies,Romantic Films,Roma...  English, Portuguese
# 10532  Social & Cultural Documentaries,Biographical D...              English
# 10533  Australian Comedies,Romantic Comedies,Australi...              English
# 10534      Stand-up Comedy,International Movies,Comedies                Dutch
#
#       Series or Movie  Hidden Gem Score  \
# 0              Series               4.3
# 1               Movie               7.0
# 2               Movie               6.4
# 3               Movie               8.1
# 4               Movie               8.6
# ...               ...               ...
# 10530           Movie               3.4
# 10531           Movie               3.1
# 10532           Movie               8.2
# 10533           Movie               8.6
# 10534           Movie               8.8
#
#                                     Country Availability       Runtime  \
# 0                                               Thailand  < 30 minutes
# 1                                                 Canada      1-2 hour
# 2                                                 Canada      1-2 hour
# 3      Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# 4                                               Thailand       > 2 hrs
# ...                                                  ...           ...
# 10530                                             France      1-2 hour
# 10531  Hungary,Lithuania,Romania,United Kingdom,Belgi...      1-2 hour
# 10532  Hungary,Lithuania,India,Australia,United Kingd...      1-2 hour
# 10533                                          Australia      1-2 hour
# 10534                                            Belgium      1-2 hour
#
#                     Director  \
# 0            Tomas Alfredson
# 1              Coky Giedroyc
# 2              Brendan Walsh
# 3              Stephen Irwin
# 4              Mez Tharatorn
# ...                      ...
# 10530    Patrick Alessandrin
# 10531            Gary Winick
# 10532    Jason Spingarn-Koff
# 10533             Amos Gitai
# 10534  Doesjka van Hoogdalem
#
#                                                   Writer  ... IMDb Score  \
# 0                                  John Ajvide Lindqvist  ...        7.9
# 1                                          Caitlin Moran  ...        5.8
# 2                             Brendan Walsh, Daley Nixon  ...        4.3
# 3                                                Unknown  ...        6.3
# 4      Pattaranad Bhiboonsawade, Thodsapon Thiptinnak...  ...        7.4
# ...                                                  ...  ...        ...
# 10530                                         Luc Besson  ...        6.5
# 10531                        Josh Goldsmith, Cathy Yuspa  ...        6.2
# 10532                                            Unknown  ...        6.2
# 10533                                            Unknown  ...        7.3
# 10534                                      Daniël Arends  ...        7.8
#
#       Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                      98.0              82.0             74.0
# 1                      79.0              69.0              1.0
# 2                      -1.0              46.0              0.0
# 3                      -1.0              -1.0              0.0
# 4                      -1.0              -1.0              0.0
# ...                     ...               ...              ...
# 10530                  75.0              64.0              0.0
# 10531                  65.0              57.0              0.0
# 10532                  89.0              65.0              1.0
# 10533                  -1.0              -1.0              0.0
# 10534                  -1.0              -1.0              0.0
#
#        Awards Nominated For    Boxoffice  Netflix Release Date  \
# 0                      57.0   $2,122,065            2021-03-04
# 1                       0.0      $70,632            2021-03-04
# 2                       0.0      $16,263            2021-03-04
# 3                       4.0           $0            2021-03-04
# 4                       0.0           $0            2021-03-03
# ...                     ...          ...                   ...
# 10530                   1.0      $36,136            2015-04-14
# 10531                  11.0  $57,231,747            2015-04-14
# 10532                   0.0           $0            2015-04-14
# 10533                   0.0           $0            2015-04-14
# 10534                   0.0           $0            2015-04-14
#
#                                    Production House IMDb Votes Trailer Site
# 0                         Canal+, Sandrew Metronome   205926.0      Unknown
# 1            Film 4, Monumental Pictures, Lionsgate     2838.0      YouTube
# 2                                           Unknown     1720.0      YouTube
# 3                                           Unknown       63.0      Unknown
# 4                                           Unknown      131.0      YouTube
# ...                                             ...        ...          ...
# 10530                                       Unknown    42967.0      YouTube
# 10531  Revolution Studios, Thirteen Productions LLC   167842.0      YouTube
# 10532                                       Unknown      878.0      Unknown
# 10533                                       Unknown       14.0      Unknown
# 10534                                       Unknown      174.0      Unknown
#
# [10535 rows x 22 columns]

# %%
sns.pairplot(numeriques, diag_kind='kde')

# %% [markdown]
# # Exploration

# %%
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()
data_acp_scaled = scaler.fit_transform(numeriques)

pca = PCA(n_components=None)
data_acp = pca.fit_transform(data_acp_scaled)

# %%
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel("Nombre de composantes")
plt.ylabel("Variance cumulée")
plt.title("Variance expliquée par l'ACP")
plt.grid()
plt.show()

# %%
composantes = pca.components_.T # (variables, composantes)
features = numeriques.columns
df_contributions = pd.DataFrame({
    'PC1': composantes[:, 0],
    'PC2': composantes[:, 1] 
}, index=features)

print(df_contributions.abs().sort_values(by='PC1', ascending=False))
print(df_contributions.abs().sort_values(by='PC2', ascending=False))
# Out:
#                             PC1       PC2
# Awards Nominated For   0.460582  0.068378
# Awards Received        0.439260  0.108912
# Metacritic Score       0.428874  0.193505
# IMDb Votes             0.417683  0.074423
# Rotten Tomatoes Score  0.371344  0.068523
# IMDb Score             0.245303  0.626866
# Hidden Gem Score       0.196098  0.736766
#                             PC1       PC2
# Hidden Gem Score       0.196098  0.736766
# IMDb Score             0.245303  0.626866
# Metacritic Score       0.428874  0.193505
# Awards Received        0.439260  0.108912
# IMDb Votes             0.417683  0.074423
# Rotten Tomatoes Score  0.371344  0.068523
# Awards Nominated For   0.460582  0.068378

# %%
plt.figure(figsize=(8, 8))
for i in range(len(features)):
    plt.arrow(0, 0, df_contributions.iloc[i, 0], df_contributions.iloc[i, 1], color='r', alpha=0.5)
    plt.text(df_contributions.iloc[i, 0]*1.1, df_contributions.iloc[i, 1]*1.1, features[i], fontsize=9)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Contributions des variables")
plt.grid()
plt.show()

# %%
plt.scatter(data_acp[:, 0], data_acp[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Projection en 2D par ACP")
plt.show()
